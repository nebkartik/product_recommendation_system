# %%
import pandas as pd
import os

# %%
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Admin\\OneDrive\\Documents\\Sample Projects\\product_recommendation_system\\experiments'

# %%
root = os.path.dirname(os.getcwd())

# %%
root
# Out:
# 'c:\\Users\\Admin\\OneDrive\\Documents\\Sample Projects\\product_recommendation_system'

# %%
data_path = os.path.join(root, "data", "flipkart_product_review.csv")

# %%
data_path
# Out:
# 'c:\\Users\\Admin\\OneDrive\\Documents\\Sample Projects\\product_recommendation_system\\data\\flipkart_product_review.csv'

# %%
# def doc_converter(self):
docs = []
df = pd.read_csv(data_path)[['product_id', 'review']]
# for _, row in df.iterrows():    
#     docs.append(Document(
#         page_content=row['review'],
#         metadata={'product_id': row['product_id']}
#     ))
# chunker = RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=50)
# chunks = chunker.split_documents(docs)
df.head()
        # return chunk
# Out:
#          product_id                                             review
# 0  ACCFZGAQJGYCYDCM  1-more flexible2-bass is very high3-sound clar...
# 1  ACCFZGAQJGYCYDCM     Super sound and good looking I like that prize
# 2  ACCFZGAQJGYCYDCM  Very much satisfied with the device at this pr...
# 3  ACCFZGAQJGYCYDCM  Nice headphone, bass was very good and sound i...
# 4  ACCFZGAQJGYCYDCM  Sound quality super battery backup super quali...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   product_id  450 non-null    object
#  1   review      450 non-null    object
# dtypes: object(2)
# memory usage: 7.2+ KB

# %%
df['product_id'].nunique()
# Out:
# 9

# %%
df[df['product_id']=='ACCFZGAQJGYCYDCM']
# Out:
#           product_id                                             review
# 0   ACCFZGAQJGYCYDCM  1-more flexible2-bass is very high3-sound clar...
# 1   ACCFZGAQJGYCYDCM     Super sound and good looking I like that prize
# 2   ACCFZGAQJGYCYDCM  Very much satisfied with the device at this pr...
# 3   ACCFZGAQJGYCYDCM  Nice headphone, bass was very good and sound i...
# 4   ACCFZGAQJGYCYDCM  Sound quality super battery backup super quali...
# 5   ACCFZGAQJGYCYDCM  Wowwww it's amezing bluetooth nice look, nice ...
# 6   ACCFZGAQJGYCYDCM  Awesome colour! Amazing experience .. but only...
# 7   ACCFZGAQJGYCYDCM  For the first time, I am posting a review, jus...
# 8   ACCFZGAQJGYCYDCM  First of all the Delivery boy is a good guy. N...
# 9   ACCFZGAQJGYCYDCM  This headphone is good but not that much as i ...
# 10  ACCFZGAQJGYCYDCM  It's a very good product ... I'm so happy with...
# 11  ACCFZGAQJGYCYDCM  Nice build quality.. bass is best it self.. vi...
# ...

# %%
grouped_df = df.groupby('product_id',as_index=False)['review'].sum()

# %%
grouped_df.reset_index()
# Out:
#    index        product_id                                             review
# 0      0  ACCEVQZABYWJHRHF  Very Good sound clarity with bass, build quali...
# 1      1  ACCFHGZFS7GB9CVM  I will tell you some hidden features that you ...
# 2      2  ACCFKYE2ARGG67WC  Nice head set good fit nice quality good to ha...
# 3      3  ACCFR3Q77R6RRGAC  first of all with mi 18 watt charger,it got fu...
# 4      4  ACCFSDGXX3S6DVBG  (1) Worth of the money 💰(2) Nice design & comf...
# 5      5  ACCFSKBJYWZKXGCP  I am very happy with this product. The U&I Tit...
# 6      6  ACCFVA3KZ2EYMYX3  Good battery 🔋 👌 Sound awesome 👌 Bass 🔊  super...
# 7      7  ACCFVWN4PGNTEFGY  Amazing Product, bass is amazing and easy to c...
# 8      8  ACCFZGAQJGYCYDCM  1-more flexible2-bass is very high3-sound clar...

# %%
grouped_df
# Out:
#          product_id                                             review
# 0  ACCEVQZABYWJHRHF  Very Good sound clarity with bass, build quali...
# 1  ACCFHGZFS7GB9CVM  I will tell you some hidden features that you ...
# 2  ACCFKYE2ARGG67WC  Nice head set good fit nice quality good to ha...
# 3  ACCFR3Q77R6RRGAC  first of all with mi 18 watt charger,it got fu...
# 4  ACCFSDGXX3S6DVBG  (1) Worth of the money 💰(2) Nice design & comf...
# 5  ACCFSKBJYWZKXGCP  I am very happy with this product. The U&I Tit...
# 6  ACCFVA3KZ2EYMYX3  Good battery 🔋 👌 Sound awesome 👌 Bass 🔊  super...
# 7  ACCFVWN4PGNTEFGY  Amazing Product, bass is amazing and easy to c...
# 8  ACCFZGAQJGYCYDCM  1-more flexible2-bass is very high3-sound clar...

# %%
pd.set_option('display.max_rows',None)

# %%
review = grouped_df[grouped_df['product_id']=='ACCFZGAQJGYCYDCM']['review']

# %%
len(str(review))
# Out:
# 82

# %%
 for _, row in df.iterrows():    
            docs.append(Document(
                page_content=row['review'],
                metadata={'product_id': row['product_id']}
            ))

# %%
docs[:10]
# Out:
# [Document(metadata={'product_id': 'ACCFZGAQJGYCYDCM'}, page_content="1-more flexible2-bass is very high3-sound clarity is good 4-battery back up to 6 to 8 hour's 5-main thing is fastest charging system is available in that. Only 20 min charge and get long up to 4 hours back up 6-killing look awesome 7-for gaming that product does not support 100% if you want for gaming then I'll recommend you please don't buy but you want for only music then this product is very well for you.. 8-no more wireless headphones are comparing with that headphones at this pric..."),
#  Document(metadata={'product_id': 'ACCFZGAQJGYCYDCM'}, page_content='Super sound and good looking I like that prize'),
# ...

# %%
chunker = RecursiveCharacterTextSplitter(chunk_size=200,chunk_overlap=50,separators = ['.'])
chunks = chunker.split_documents(docs[:10])

# %%
chunks
# Out:
# [Document(metadata={'product_id': 'ACCFZGAQJGYCYDCM'}, page_content="1-more flexible2-bass is very high3-sound clarity is good 4-battery back up to 6 to 8 hour's 5-main thing is fastest charging system is available in that"),
#  Document(metadata={'product_id': 'ACCFZGAQJGYCYDCM'}, page_content=". Only 20 min charge and get long up to 4 hours back up 6-killing look awesome 7-for gaming that product does not support 100% if you want for gaming then I'll recommend you please don't buy but you want for only music then this product is very well for you"),
#  Document(metadata={'product_id': 'ACCFZGAQJGYCYDCM'}, page_content='.. 8-no more wireless headphones are comparing with that headphones at this pric...'),
#  Document(metadata={'product_id': 'ACCFZGAQJGYCYDCM'}, page_content='Super sound and good looking I like that prize'),
# ...

# %%
# Token Chunking
from langchain_text_splitters import TokenTextSplitter

# %%
chunker = TokenTextSplitter(chunk_size=200, chunk_overlap=20,separators = ['.'])
chunks = chunker.split_documents(docs[:10])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 chunker = TokenTextSplitter(chunk_size=200, chunk_overlap=20,separators = ['.'])
#       2 chunks = chunker.split_documents(docs[:10])
#
# File c:\Users\Admin\OneDrive\Documents\Sample Projects\product_recommendation_system\product_recommender\Lib\site-packages\langchain_text_splitters\base.py:322, in TokenTextSplitter.__init__(self, encoding_name, model_name, allowed_special, disallowed_special, **kwargs)
#     301 def __init__(
#     302     self,
#     303     encoding_name: str = "gpt2",
#    (...)    307     **kwargs: Any,
#     308 ) -> None:
#     309     """Create a new `TextSplitter`.
#     310
#     311     Args:
#    (...)    320         ImportError: If the tiktoken package is not installed.
#     321     """
# --> 322     super().__init__(**kwargs)
#     323     if not _HAS_TIKTOKEN:
# ...

# %%
chunks
# Out:
# [Document(metadata={'product_id': 'ACCFZGAQJGYCYDCM'}, page_content="1-more flexible2-bass is very high3-sound clarity is good 4-battery back up to 6 to 8 hour's 5-main thing is fastest charging system is available in that. Only 20 min charge and get long up to 4 hours back up 6-killing look awesome 7-for gaming that product does not support 100% if you want for gaming then I'll recommend you please don't buy but you want for only music then this product is very well for you.. 8-no more wireless headphones are comparing with that headphones at this pric..."),
#  Document(metadata={'product_id': 'ACCFZGAQJGYCYDCM'}, page_content='Super sound and good looking I like that prize'),
# ...
